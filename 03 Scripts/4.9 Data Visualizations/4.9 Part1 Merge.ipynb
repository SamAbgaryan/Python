# %%
import pandas as pd
import numpy as np
import os

# %%
path=r"C:\Users\Sam\Desktop\CF\Project 4 Instacart Basket\Instacart Basket Analysis\02 Data\Prepared Data"

# %%
df=pd.read_pickle(os.path.join(path,"customer_cleaned.pkl"))

# %%
df_1=pd.read_pickle(os.path.join(path,"instacart_merge_dropped.pkl"))

# %%
df_1.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  order_dow  ...  price_range_loc  \
# 0   3139998      138    prior            28          6  ...        Mid-range
# 1   1977647      138    prior            30          6  ...        Mid-range
# 2    389851      709    prior             2          0  ...        Mid-range
# 3    652770      764    prior             1          3  ...        Mid-range
# 4   1813452      764    prior             3          4  ...        Mid-range
#
# ...

# %%
df.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants marital_status  income
# 0                     3        married  165665
# 1                     0         single   59285
# 2                     2        married   99568
# 3                     0         single   42049
# 4                     1        married   40374

# %%
# merging
df_merged=df.merge(df_1,on=["user_id"],indicator=True)

# %%
df_merged.head()
# Out:
#    user_id first_name last_name  gender     state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
#
#    number_of_dependants marital_status  income  ...   busiest_day  \
# 0                     3        married  165665  ...  Regular Busy
# 1                     3        married  165665  ...  Regular Busy
# 2                     3        married  165665  ...  Regular Busy
# 3                     3        married  165665  ...  Regular Busy
# 4                     3        married  165665  ...  Regular Busy
#
#    busiest_days  busiest_period_of_day  max_order  loyalty_flag  \
# 0  Busiest days            Most orders          8  New customer
# ...

# %%
#exporting
df_merged.to_pickle(os.path.join(path,"customer_instacart_merged.pkl"))
