# %% [markdown]
# # Imprting libraries and data

# %%
import pandas as pd
import numpy as np
import os
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\Sam\Desktop\CF\Project 4 Instacart Basket\Instacart Basket Analysis\02 Data\Prepared Data"

# %%
df=pd.read_pickle(os.path.join(path,"customer_instacart_merged.pkl"))

# %%
df.columns
# Out:
# Index(['user_id', 'first_name', 'last_name', 'gender', 'state', 'age',
#        'date_joined', 'number_of_dependants', 'marital_status', 'income',
#        'product_id', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'order_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order', 'add_to_cart_order',
#        'reordered', 'price_range_loc', 'busiest_day', 'busiest_days',
#        'busiest_period_of_day', 'max_order', 'loyalty_flag', 'average_price',
#        'spending_flag', 'median_days_between_orders', 'order_frequency',
#        '_merge'],
#       dtype='object')

# %%
# creating a histogram for the order_hour_of_day
df["order_hour_of_day"].plot.hist(bins=24)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## The histogram shows the frequncy of orders placed per hour of the day. I decided to have the bins equal to 24 to get a cleared picture per single hour. Based on the histogram, the busiest hout of the day for order placing is around 10am.

# %%
# creating a bar chart with the loyalty_flag variable
df["loyalty_flag"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='loyalty_flag'>

# %% [markdown]
# ## the bar chart shows that there are more regular customers than loyal or new ones.

# %%
# creating a linechart on prices and hour of the day
lineprice=sns.lineplot(data=df,y="prices",x="order_hour_of_day")
# Out:
# C:\Users\Sam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## I've decided to run code without creating a reliable sample, because I wanted to see if my will be able to execute without running into a memory error and how long it will take to execute. It took about 15 min but it was succesfully done :)

# %%
# creating a linechart to shows the relationship between age and number of dependents
line=sns.lineplot(data=df,x="age",y="number_of_dependants")
# Out:
# C:\Users\Sam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Sam\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## The line chart does not show a clear pattern or correlation between the variables. There are major ups and downs, which would probably be seen clearer with a more detailed chart. If I was to draw an average line for this chart it would be right at 1.5 mark.

# %%
# creating a scatterplot for age and income
scaterplot=sns.scatterplot(data=df,x="income",y="age")

# %% [markdown]
# ### The scatterplot indicates that the age of really high income earners (400K and above) is over 40 years of age.

# %%
# exporting the charts
path1=r"C:\Users\Sam\Desktop\CF\Project 4 Instacart Basket\Instacart Basket Analysis\04 Analysis\Visualizations"
scaterplot.figure.savefig(os.path.join(path1,"age_income_scatterplot.png"))
line.figure.savefig(os.path.join(path1,"line_age_dependents.png"))
lineprice.figure.savefig(os.path.join(path1,"line_price_hour.png"))
